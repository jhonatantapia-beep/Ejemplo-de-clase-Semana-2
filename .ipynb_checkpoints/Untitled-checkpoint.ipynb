# %%
import geopandas as gpd

# from zip
linkGitZip="https://github.com/jhonatantapia-beep/Ejemplo-de-clase-Semana-2/raw/refs/heads/main/Archivos-mapas/World_Countries.zip"
gdf1 = gpd.read_file(linkGitZip)
gdf1.head()
# Out:
#                COUNTRY                                           geometry
# 0  Aruba (Netherlands)  POLYGON ((-69.88223 12.41111, -69.94695 12.436...
# 1  Antigua and Barbuda  MULTIPOLYGON (((-61.73889 17.54055, -61.75195 ...
# 2          Afghanistan  POLYGON ((61.27656 35.60725, 61.29638 35.62853...
# 3              Algeria  POLYGON ((-5.15213 30.18047, -5.13917 30.19236...
# 4           Azerbaijan  MULTIPOLYGON (((46.54037 38.87559, 46.49554 38...

# %%
gdf1.plot()
# Out:
# <Axes: >

# %%
import geopandas as gpd

# from zip
linkGitZip="https://github.com/jhonatantapia-beep/Ejemplo-de-clase-Semana-2/raw/refs/heads/main/Archivos-mapas/World_Cities.zip"
gdf2 = gpd.read_file(linkGitZip)
gdf2.head()
# Out:
#                NAME COUNTRY CAPITAL                   geometry
# 0          Murmansk  Russia       N  POINT (33.08604 68.96355)
# 1       Arkhangelsk  Russia       N  POINT (40.64616 64.52067)
# 2  Saint Petersburg  Russia       N  POINT (30.45333 59.95189)
# 3           Magadan  Russia       N   POINT (150.78001 59.571)
# 4             Perm'  Russia       N  POINT (56.23246 58.00024)

# %%
gdf2.plot()
# Out:
# <Axes: >

# %%
import geopandas as gpd

# from zip
linkGitZip="https://github.com/jhonatantapia-beep/Ejemplo-de-clase-Semana-2/raw/refs/heads/main/Archivos-mapas/World_Hydrography.zip"
gdf3 = gpd.read_file(linkGitZip)
gdf3.head()
# Out:
#         NAME  SYSTEM                                           geometry
# 0      Aldan    Lena  LINESTRING (124.00678 56.47258, 123.25956 56.6...
# 1     Amazon  Amazon  MULTILINESTRING ((-61.2773 -3.60706, -60.68466...
# 2  Amu Darya    None  LINESTRING (73.98818 37.49952, 73.52595 37.528...
# 3       Amur    None  LINESTRING (122.63956 49.9973, 120.47874 49.25...
# 4     Angara    None  LINESTRING (105.07841 51.93053, 103.92959 51.7...

# %%
gdf3.plot()
# Out:
# <Axes: >

# %%
import geopandas as gpd

# from zip
linkGitZip="https://github.com/jhonatantapia-beep/Ejemplo-de-clase-Semana-2/raw/refs/heads/main/Archivos-mapas/bra_admbnda_adm1_ibge_2020.zip"
gdf4 = gpd.read_file(linkGitZip)
gdf4.head()
# Out:
#   ADM0_EN ADM0_PT ADM0_PCODE   ADM1_PT ADM1_PCODE  \
# 0  Brazil  Brasil         BR      Acre       BR12
# 1  Brazil  Brasil         BR   Alagoas       BR27
# 2  Brazil  Brasil         BR     Amapá       BR16
# 3  Brazil  Brasil         BR  Amazonas       BR13
# 4  Brazil  Brasil         BR     Bahia       BR29
#
#                                             geometry
# 0  MULTIPOLYGON (((-68.87747 -11.01987, -68.88027...
# 1  POLYGON ((-35.46317 -8.82467, -35.46457 -8.828...
# 2  MULTIPOLYGON (((-50.46147 2.11133, -50.45627 2...
# 3  MULTIPOLYGON (((-58.49367 -0.84197, -58.48917 ...
# 4  MULTIPOLYGON (((-38.70687 -17.96447, -38.70867...

# %%
gdf4.plot()
# Out:
# <Axes: >

# %%
import geopandas as gpd

# from zip
linkGitZip="https://github.com/jhonatantapia-beep/Ejemplo-de-clase-Semana-2/raw/refs/heads/main/Archivos-mapas/bra_admbnda_adm2_ibge_2020.zip"
gdf5 = gpd.read_file(linkGitZip)
gdf5.head()
# Out:
#   ADM0_EN ADM0_PT ADM0_PCODE   ADM1_PT ADM1_PCODE                ADM2_PT  \
# 0  Brazil  Brasil         BR  Rondônia       BR11  Alta Floresta D'Oeste
# 1  Brazil  Brasil         BR  Rondônia       BR11              Ariquemes
# 2  Brazil  Brasil         BR  Rondônia       BR11                 Cabixi
# 3  Brazil  Brasil         BR  Rondônia       BR11                 Cacoal
# 4  Brazil  Brasil         BR  Rondônia       BR11             Cerejeiras
#
#   ADM2_PCODE  ET_ID                                           geometry
# 0  BR1100015      0  POLYGON ((-62.0495 -11.86731, -62.04559 -11.86...
# 1  BR1100023      1  POLYGON ((-62.42279 -9.80481, -62.42688 -9.806...
# 2  BR1100031      2  POLYGON ((-60.37329 -13.40887, -60.37323 -13.4...
# 3  BR1100049      3  POLYGON ((-61.00061 -10.99219, -61.00061 -11.0...
# 4  BR1100056      4  POLYGON ((-61.20642 -13.08759, -61.20282 -13.0...

# %%
gdf5.plot()
# Out:
# <Axes: >
